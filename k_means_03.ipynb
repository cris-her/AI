# %% [markdown]
# <a href="https://colab.research.google.com/github/cris-her/AI/blob/master/k_means_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Ejemplo Machine Learning No Supervisado</h1>

# %% [markdown]
# Vamos a utilizar k-means de scikitlearn con un ejemplo bastante sencillo, utilizando datos generados con el make_blobs del mismo scikitlearn

# %%
# importar las librerías para los gráficos
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
# importar numpy python
import numpy as np

# %%
# importar el sample generator de scikit-learn - make blobs
from sklearn.datasets.samples_generator import make_blobs
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# graficarlo
X,Y = make_blobs(n_samples=500, centers=4)

plt.scatter(X[:,0], X[:,1], s=50)

# %%
# K-means de scikit-learn
from sklearn.cluster import KMeans

# %%
# K-means
kmeans = KMeans(n_clusters=3)

# %%
# entrenar el algoritmo
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
# cluster labels
y_means = kmeans.predict(X)

# %%
# centroid values
centers = kmeans.cluster_centers_
print(centers)
# Out:
# [[-8.90108297  7.65188123]
#  [-2.48065943  4.61846313]
#  [ 3.73715634  2.42562805]]

# %%
# graficar valores conjuntos
plt.scatter(X[:,0], X[:,1], c=y_means, cmap='viridis')

# incluidos los centroides
plt.scatter(centers[:,0], centers[:,1], c='black', s=200, alpha=0.5);
